# %% [markdown]
# ## Pulling data from public APIs - GET request

# %%
base_url = "http://api.exchangeratesapi.io/v1/latest?access_key=########################################"

# %% [markdown]
# ## Extracting data on currency exchange rates

# %% [markdown]
# ### Sending a GET request

# %%
import requests

# %%
response = requests.get(base_url)

# %% [markdown]
# ### Investigating the response

# %%
# To check that the response sent without problems
response.ok
# Out:
# True

# %%
# To access the status code directly
response.status_code
# Out:
# 200

# %%
# To show the body of the response
response.text
# Out:
# '{"success":true,"timestamp":1637437444,"base":"EUR","date":"2021-11-20","rates":{"AED":4.143174,"AFN":105.357692,"ALL":121.258902,"AMD":537.922958,"ANG":2.031776,"AOA":670.284998,"ARS":113.356104,"AUD":1.558503,"AWG":2.030729,"AZN":1.922123,"BAM":1.953226,"BBD":2.276224,"BDT":96.634375,"BGN":1.95431,"BHD":0.425421,"BIF":2244.509337,"BMD":1.128026,"BND":1.534627,"BOB":7.784395,"BRL":6.332293,"BSD":1.127377,"BTC":1.8965832e-5,"BTN":83.71113,"BWP":13.148473,"BYN":2.782191,"BYR":22109.316676,"BZD":2.272429,"CAD":1.426288,"CDF":2262.821288,"CHF":1.047374,"CLF":0.03387,"CLP":934.574253,"CNY":7.204935,"COP":4415.095177,"CRC":721.591368,"CUC":1.128026,"CUP":29.892699,"CVE":110.106517,"CZK":25.422222,"DJF":200.473289,"DKK":7.434939,"DOP":63.72927,"DZD":157.070049,"EGP":17.716561,"ERN":16.920746,"ETB":53.740648,"EUR":1,"FJD":2.369363,"FKP":0.840869,"GBP":0.838993,"GEL":3.525128,"GGP":0.840869,"GHS":6.907857,"GIP":0.840869,"GMD":59.112928,"GNF":10769.598642,"GTQ":8.720149,"GYD":235.880482,"HKD":8.788465,"HNL":27.184871,"HRK":7.508035,"HTG":110.546883,"HUF":367.601668,"IDR":16096.202955,"ILS":3.492731,"IMP":0.840869,"INR":83.824598,"IQD":1644.958135,"IRR":47659.114151,"ISK":147.794449,"JEP":0.840869,"JMD":175.447132,"JOD":0.799815,"JPY":128.620994,"KES":126.373227,"KGS":95.634531,"KHR":4586.504952,"KMF":488.43581,"KPW":1015.22412,"KRW":1344.314568,"KWD":0.34133,"KYD":0.939548,"KZT":488.70856,"LAK":12080.682475,"LBP":1704.897175,"LKR":227.74638,"LRD":161.308163,"LSL":17.642763,"LTL":3.330769,"LVL":0.682332,"LYD":5.178746,"MAD":10.385751,"MDL":19.956299,"MGA":4498.155523,"MKD":61.532978,"MMK":1997.572355,"MNT":3224.14594,"MOP":9.048878,"MRO":402.705217,"MUR":48.859485,"MVR":17.428434,"MWK":919.399651,"MXN":23.514165,"MYR":4.719103,"MZN":72.002348,"NAD":17.642758,"NGN":463.438775,"NIO":39.716833,"NOK":9.937834,"NPR":133.938088,"NZD":1.608249,"OMR":0.434268,"PAB":1.127377,"PEN":4.537669,"PGK":3.959552,"PHP":56.974078,"PKR":197.475918,"PLN":4.697219,"PYG":7716.99245,"QAR":4.107187,"RON":4.949897,"RSD":117.668534,"RUB":82.93081,"RWF":1166.87045,"SAR":4.231436,"SBD":9.078755,"SCR":16.834708,"SDG":494.075929,"SEK
":9.937834,"NPR":133.938088,"NZD":1.608249,"OMR":0.434268,"PAB":1.127377,"PEN":4.537669,"PGK":3.959552,"PHP":56.974078,"PKR":197.475918,"PLN":4.697219,"PYG":7716.99245,"QAR":4.107187,"RON":4.949897,"RSD":117.668534,"RUB":82.93081,"RWF":1166.87045,"SAR":4.231436,"SBD":9.078755,"SCR":16.834708,"SDG":494.075929,"SEK":10.135712,"SGD":1.535667,"SHP":1.553748,"SLL":12436.491012,"SOS":658.767777,"SRD":24.249226,"STD":23347.868197,"SVC":9.864801,"SYP":1417.684984,"SZL":17.754744,"THB":37.038788,"TJS":12.734825,"TMT":3.948092,"TND":3.229258,"TOP":2.550134,"TRY":12.671012,"TTD":7.652086,"TWD":31.358573,"TZS":2596.717062,"UAH":29.977973,"UGX":4030.298938,"USD":1.128026,"UYU":49.7444,"UZS":12110.606778,"VEF":241206127582.57767,"VND":25563.333394,"VUV":125.571453,"WST":2.891855,"XAF":655.072186,"XAG":0.04583,"XAU":0.000611,"XCD":3.048548,"XDR":0.804813,"XOF":655.014197,"XPF":118.86582,"YER":282.289007,"ZAR":17.716212,"ZMK":10153.594934,"ZMW":19.8697,"ZWL":363.224028}}'

# %% [markdown]
# ### Handling the JSON

# %%
# The 'requests' library provides us with the '.json()' method, 
# which converts a JSON formatted response to a native Python object
response.json()
# Out:
# {'success': True,
#  'timestamp': 1637437444,
#  'base': 'EUR',
#  'date': '2021-11-20',
#  'rates': {'AED': 4.143174,
#   'AFN': 105.357692,
#   'ALL': 121.258902,
#   'AMD': 537.922958,
#   'ANG': 2.031776,
#   'AOA': 670.284998,
#   'ARS': 113.356104,
#   'AUD': 1.558503,
#   'AWG': 2.030729,
#   'AZN': 1.922123,
#   'BAM': 1.953226,
#   'BBD': 2.276224,
#   'BDT': 96.634375,
#   'BGN': 1.95431,
#   'BHD': 0.425421,
#   'BIF': 2244.509337,
#   'BMD': 1.128026,
#   'BND': 1.534627,
#   'BOB': 7.784395,
#   'BRL': 6.332293,
#   'BSD': 1.127377,
#   'BTC': 1.8965832e-05,
#   'BTN': 83.71113,
#   'BWP': 13.148473,
#   'BYN': 2.782191,
#   'BYR': 22109.316676,
#   'BZD': 2.272429,
#   'CAD': 1.426288,
#   'CDF': 2262.821288,
#   'CHF': 1.047374,
#   'CLF': 0.03387,
#   'CLP': 934.574253,
#   'CNY': 7.204935,
#   'COP': 4415.095177,
#   'CRC': 721.591368,
#   'CUC': 1.128026,
#   'CUP': 29.892699,
#   'CVE': 110.106517,
#   'CZK': 25.422222,
#   'DJF': 200.473289,
#   'DKK': 7.434939,
#   'DOP': 63.72927,
#   'DZD': 157.070049,
#   'EGP': 17.716561,
#   'ERN': 16.920746,
#   'ETB': 53.740648,
#   'EUR': 1,
#   'FJD': 2.369363,
#   'FKP': 0.840869,
#   'GBP': 0.838993,
#   'GEL': 3.525128,
#   'GGP': 0.840869,
#   'GHS': 6.907857,
#   'GIP': 0.840869,
#   'GMD': 59.112928,
#   'GNF': 10769.598642,
#   'GTQ': 8.720149,
#   'GYD': 235.880482,
#   'HKD': 8.788465,
#   'HNL': 27.184871,
#   'HRK': 7.508035,
#   'HTG': 110.546883,
#   'HUF': 367.601668,
#   'IDR': 16096.202955,
#   'ILS': 3.492731,
#   'IMP': 0.840869,
#   'INR': 83.824598,
#   'IQD': 1644.958135,
#   'IRR': 47659.114151,
#   'ISK': 147.794449,
#   'JEP': 0.840869,
#   'JMD': 175.447132,
#   'JOD': 0.799815,
#   'JPY': 128.620994,
#   'KES': 126.373227,
#   'KGS': 95.634531,
#   'KHR': 4586.504952,
#   'KMF': 488.43581,
#   'KPW': 1015.22412,
#   'KRW': 1344.314568,
#   'KWD': 0.34133,
#   'KYD': 0.939548,
#   'KZT': 488.70856,
#   'LAK': 12080.682475,
#   'LBP': 1704.897175,
#   'LKR': 227.74638,
#   'LRD': 161.308163,
#   'LSL': 17.642763,
#   'LTL': 3.330769,
#   'LVL': 0.682332,
#   'LYD': 5.178746,
#   'MAD': 10.385751,
#   'MDL': 19.956299,
#   'MGA': 4498.155523,
#   'MKD': 61.532978,
#   'MMK': 1997.572355,
#   'MNT': 3224.14594,
#   'MOP': 9.048878,
#   'MRO': 402.705217,
#   'MUR': 48.859485,
#   'MVR': 17.428434,
#   'MWK': 919.399651,
#   'MXN': 23.514165,
#   'MYR': 4.719103,
#   'MZN': 72.002348,
#   'NAD': 17.642758,
#   'NGN': 463.438775,
#   'NIO': 39.716833,
#   'NOK': 9.937834,
#   'NPR': 133.938088,
#   'NZD': 1.608249,
#   'OMR': 0.434268,
#   'PAB': 1.127377,
#   'PEN': 4.537669,
#   'PGK': 3.959552,
#   'PHP': 56.974078,
#   'PKR': 197.475918,
#   'PLN': 4.697219,
#   'PYG': 7716.99245,
#   'QAR': 4.107187,
#   'RON': 4.949897,
#   'RSD': 117.668534,
#   'RUB': 82.93081,
#   'RWF': 1166.87045,
#   'SAR': 4.231436,
#   'SBD': 9.078755,
#   'SCR': 16.834708,
#   'SDG': 494.075929,
#   'SEK': 10.135712,
#   'SGD': 1.535667,
#   'SHP': 1.553748,
#   'SLL': 12436.491012,
#   'SOS': 658.767777,
#   'SRD': 24.249226,
#   'STD': 23347.868197,
#   'SVC': 9.864801,
#   'SYP': 1417.684984,
#   'SZL': 17.754744,
#   'THB': 37.038788,
#   'TJS': 12.734825,
#   'TMT': 3.948092,
#   'TND': 3.229258,
#   'TOP': 2.550134,
#   'TRY': 12.671012,
#   'TTD': 7.652086,
#   'TWD': 31.358573,
#   'TZS': 2596.717062,
#   'UAH': 29.977973,
#   'UGX': 4030.298938,
#   'USD': 1.128026,
#   'UYU': 49.7444,
#   'UZS': 12110.606778,
#   'VEF': 241206127582.57767,
#   'VND': 25563.333394,
#   'VUV': 125.571453,
#   'WST': 2.891855,
#   'XAF': 655.072186,
#   'XAG': 0.04583,
#   'XAU': 0.000611,
#   'XCD': 3.048548,
#   'XDR': 0.804813,
#   'XOF': 655.014197,
#   'XPF': 118.86582,
#   'YER': 282.289007,
#   'ZAR': 17.716212,
#   'ZMK': 10153.594934,
#   'ZMW': 19.8697,
#   'ZWL': 363.224028}}

# %%
type(response.json())
# Out:
# dict

# %%
#         "TWD": 31.358573,
#         "TZS": 2596.717062,
#         "UAH": 29.977973,
#         "UGX": 4030.298938,
#         "USD": 1.128026,
#         "UYU": 49.7444,
#         "UZS": 12110.606778,
#         "VEF": 241206127582.57767,
#         "VND": 25563.333394,
#         "VUV": 125.571453,
#         "WST": 2.891855,
#         "XAF": 655.072186,
#         "XAG": 0.04583,
#         "XAU": 0.000611,
#         "XCD": 3.048548,
#         "XDR": 0.804813,
#         "XOF": 655.014197,
#         "XPF": 118.86582,
#         "YER": 282.289007,
#         "ZAR": 17.716212,
#         "ZMK": 10153.594934,
#         "ZMW": 19.8697,
#         "ZWL": 363.224028
#     }
# }

# %%
# To inspect the content of JSON
response.json().keys()
# Out:
# dict_keys(['success', 'timestamp', 'base', 'date', 'rates'])

# %% [markdown]
# ## Specifying parameters in a request
# > We will always need to refer to the api documentation. With the note that, each API has its own documentation.

# %% [markdown]
# ### Incorporating parameters in the GET request

# %%
param_url = base_url + "&symbols=USD,GBP"
param_url
# Out:
# 'http://api.exchangeratesapi.io/v1/latest?access_key=ca644efc5035c9ca014e207937f9d706&symbols=USD,GBP'

# %%
response =requests.get(param_url)
response
# Out:
# <Response [200]>

# %%
# Saving the converted JSON response to a varaible
data = response.json()
data
# Out:
# {'success': True,
#  'timestamp': 1637437444,
#  'base': 'EUR',
#  'date': '2021-11-20',
#  'rates': {'USD': 1.128026, 'GBP': 0.838993}}

# %%
data['base']
# Out:
# 'EUR'

# %%
data['date']
# Out:
# '2021-11-20'

# %%
data['rates']
# Out:
# {'USD': 1.128026, 'GBP': 0.838993}

# %%
param_url = base_url + "&symbols=GBP" + "&" + "base=EUR"
param_url
# Out:
# 'http://api.exchangeratesapi.io/v1/latest?access_key=ca644efc5035c9ca014e207937f9d706&symbols=GBP&base=EUR'

# %%
# requests.get(): for making the request.
# .json(): for transforming the response.
data = requests.get(param_url).json()
data
# Out:
# {'success': True,
#  'timestamp': 1637437444,
#  'base': 'EUR',
#  'date': '2021-11-20',
#  'rates': {'GBP': 0.838993}}

# %%
eur_to_gbp = data['rates']['GBP']
eur_to_gbp
# Out:
# 0.838993

# %% [markdown]
# ## Obtaining historical exchange rates

# %%
hist_url = base_url + "&/2016-01-26"
hist_url
# Out:
# 'http://api.exchangeratesapi.io/v1/latest?access_key=ca644efc5035c9ca014e207937f9d706&/2016-01-26'

# %%
response = requests.get(hist_url)
response
# Out:
# <Response [200]>

# %%
response.status_code
# Out:
# 200

# %%
data = response.json()
data
# Out:
# {'success': True,
#  'timestamp': 1637437444,
#  'base': 'EUR',
#  'date': '2021-11-20',
#  'rates': {'AED': 4.143174,
#   'AFN': 105.357692,
#   'ALL': 121.258902,
#   'AMD': 537.922958,
#   'ANG': 2.031776,
#   'AOA': 670.284998,
#   'ARS': 113.356104,
#   'AUD': 1.558503,
#   'AWG': 2.030729,
#   'AZN': 1.922123,
#   'BAM': 1.953226,
#   'BBD': 2.276224,
#   'BDT': 96.634375,
#   'BGN': 1.95431,
#   'BHD': 0.425421,
#   'BIF': 2244.509337,
#   'BMD': 1.128026,
#   'BND': 1.534627,
#   'BOB': 7.784395,
#   'BRL': 6.332293,
#   'BSD': 1.127377,
#   'BTC': 1.8965832e-05,
#   'BTN': 83.71113,
#   'BWP': 13.148473,
#   'BYN': 2.782191,
#   'BYR': 22109.316676,
#   'BZD': 2.272429,
#   'CAD': 1.426288,
#   'CDF': 2262.821288,
#   'CHF': 1.047374,
#   'CLF': 0.03387,
#   'CLP': 934.574253,
#   'CNY': 7.204935,
#   'COP': 4415.095177,
#   'CRC': 721.591368,
#   'CUC': 1.128026,
#   'CUP': 29.892699,
#   'CVE': 110.106517,
#   'CZK': 25.422222,
#   'DJF': 200.473289,
#   'DKK': 7.434939,
#   'DOP': 63.72927,
#   'DZD': 157.070049,
#   'EGP': 17.716561,
#   'ERN': 16.920746,
#   'ETB': 53.740648,
#   'EUR': 1,
#   'FJD': 2.369363,
#   'FKP': 0.840869,
#   'GBP': 0.838993,
#   'GEL': 3.525128,
#   'GGP': 0.840869,
#   'GHS': 6.907857,
#   'GIP': 0.840869,
#   'GMD': 59.112928,
#   'GNF': 10769.598642,
#   'GTQ': 8.720149,
#   'GYD': 235.880482,
#   'HKD': 8.788465,
#   'HNL': 27.184871,
#   'HRK': 7.508035,
#   'HTG': 110.546883,
#   'HUF': 367.601668,
#   'IDR': 16096.202955,
#   'ILS': 3.492731,
#   'IMP': 0.840869,
#   'INR': 83.824598,
#   'IQD': 1644.958135,
#   'IRR': 47659.114151,
#   'ISK': 147.794449,
#   'JEP': 0.840869,
#   'JMD': 175.447132,
#   'JOD': 0.799815,
#   'JPY': 128.620994,
#   'KES': 126.373227,
#   'KGS': 95.634531,
#   'KHR': 4586.504952,
#   'KMF': 488.43581,
#   'KPW': 1015.22412,
#   'KRW': 1344.314568,
#   'KWD': 0.34133,
#   'KYD': 0.939548,
#   'KZT': 488.70856,
#   'LAK': 12080.682475,
#   'LBP': 1704.897175,
#   'LKR': 227.74638,
#   'LRD': 161.308163,
#   'LSL': 17.642763,
#   'LTL': 3.330769,
#   'LVL': 0.682332,
#   'LYD': 5.178746,
#   'MAD': 10.385751,
#   'MDL': 19.956299,
#   'MGA': 4498.155523,
#   'MKD': 61.532978,
#   'MMK': 1997.572355,
#   'MNT': 3224.14594,
#   'MOP': 9.048878,
#   'MRO': 402.705217,
#   'MUR': 48.859485,
#   'MVR': 17.428434,
#   'MWK': 919.399651,
#   'MXN': 23.514165,
#   'MYR': 4.719103,
#   'MZN': 72.002348,
#   'NAD': 17.642758,
#   'NGN': 463.438775,
#   'NIO': 39.716833,
#   'NOK': 9.937834,
#   'NPR': 133.938088,
#   'NZD': 1.608249,
#   'OMR': 0.434268,
#   'PAB': 1.127377,
#   'PEN': 4.537669,
#   'PGK': 3.959552,
#   'PHP': 56.974078,
#   'PKR': 197.475918,
#   'PLN': 4.697219,
#   'PYG': 7716.99245,
#   'QAR': 4.107187,
#   'RON': 4.949897,
#   'RSD': 117.668534,
#   'RUB': 82.93081,
#   'RWF': 1166.87045,
#   'SAR': 4.231436,
#   'SBD': 9.078755,
#   'SCR': 16.834708,
#   'SDG': 494.075929,
#   'SEK': 10.135712,
#   'SGD': 1.535667,
#   'SHP': 1.553748,
#   'SLL': 12436.491012,
#   'SOS': 658.767777,
#   'SRD': 24.249226,
#   'STD': 23347.868197,
#   'SVC': 9.864801,
#   'SYP': 1417.684984,
#   'SZL': 17.754744,
#   'THB': 37.038788,
#   'TJS': 12.734825,
#   'TMT': 3.948092,
#   'TND': 3.229258,
#   'TOP': 2.550134,
#   'TRY': 12.671012,
#   'TTD': 7.652086,
#   'TWD': 31.358573,
#   'TZS': 2596.717062,
#   'UAH': 29.977973,
#   'UGX': 4030.298938,
#   'USD': 1.128026,
#   'UYU': 49.7444,
#   'UZS': 12110.606778,
#   'VEF': 241206127582.57767,
#   'VND': 25563.333394,
#   'VUV': 125.571453,
#   'WST': 2.891855,
#   'XAF': 655.072186,
#   'XAG': 0.04583,
#   'XAU': 0.000611,
#   'XCD': 3.048548,
#   'XDR': 0.804813,
#   'XOF': 655.014197,
#   'XPF': 118.86582,
#   'YER': 282.289007,
#   'ZAR': 17.716212,
#   'ZMK': 10153.594934,
#   'ZMW': 19.8697,
#   'ZWL': 363.224028}}

# %%
print(json.dumps(data, indent=4))
# Out:
# {
#     "success": true,
#     "timestamp": 1637437444,
#     "base": "EUR",
#     "date": "2021-11-20",
#     "rates": {
#         "AED": 4.143174,
#         "AFN": 105.357692,
#         "ALL": 121.258902,
#         "AMD": 537.922958,
#         "ANG": 2.031776,
#         "AOA": 670.284998,
#         "ARS": 113.356104,
#         "AUD": 1.558503,
#         "AWG": 2.030729,
#         "AZN": 1.922123,
#         "BAM": 1.953226,
#         "BBD": 2.276224,
#         "BDT": 96.634375,
#         "BGN": 1.95431,
#         "BHD": 0.425421,
#         "BIF": 2244.509337,
#         "BMD": 1.128026,
#         "BND": 1.534627,
#         "BOB": 7.784395,
#         "BRL": 6.332293,
#         "BSD": 1.127377,
#         "BTC": 1.8965832e-05,
#         "BTN": 83.71113,
#         "BWP": 13.148473,
#         "BYN": 2.782191,
#         "BYR": 22109.316676,
#         "BZD": 2.272429,
#         "CAD": 1.426288,
#         "CDF": 2262.821288,
#         "CHF": 1.047374,
#         "CLF": 0.03387,
#         "CLP": 934.574253,
#         "CNY": 7.204935,
#         "COP": 4415.095177,
#         "CRC": 721.591368,
#         "CUC": 1.128026,
#         "CUP": 29.892699,
#         "CVE": 110.106517,
#         "CZK": 25.422222,
#         "DJF": 200.473289,
#         "DKK": 7.434939,
#         "DOP": 63.72927,
#         "DZD": 157.070049,
#         "EGP": 17.716561,
#         "ERN": 16.920746,
#         "ETB": 53.740648,
#         "EUR": 1,
#         "FJD": 2.369363,
#         "FKP": 0.840869,
#         "GBP": 0.838993,
#         "GEL": 3.525128,
#         "GGP": 0.840869,
#         "GHS": 6.907857,
#         "GIP": 0.840869,
#         "GMD": 59.112928,
#         "GNF": 10769.598642,
#         "GTQ": 8.720149,
#         "GYD": 235.880482,
#         "HKD": 8.788465,
#         "HNL": 27.184871,
#         "HRK": 7.508035,
#         "HTG": 110.546883,
#         "HUF": 367.601668,
#         "IDR": 16096.202955,
#         "ILS": 3.492731,
#         "IMP": 0.840869,
#         "INR": 83.824598,
#         "IQD": 1644.958135,
#         "IRR": 47659.114151,
#         "ISK": 147.794449,
#         "JEP": 0.840869,
#         "JMD": 175.447132,
#         "JOD": 0.799815,
#         "JPY": 128.620994,
#         "KES": 126.373227,
#         "KGS": 95.634531,
#         "KHR": 4586.504952,
#         "KMF": 488.43581,
#         "KPW": 1015.22412,
#         "KRW": 1344.314568,
#         "KWD": 0.34133,
#         "KYD": 0.939548,
#         "KZT": 488.70856,
#         "LAK": 12080.682475,
#         "LBP": 1704.897175,
#         "LKR": 227.74638,
#         "LRD": 161.308163,
#         "LSL": 17.642763,
#         "LTL": 3.330769,
#         "LVL": 0.682332,
#         "LYD": 5.178746,
#         "MAD": 10.385751,
#         "MDL": 19.956299,
#         "MGA": 4498.155523,
#         "MKD": 61.532978,
#         "MMK": 1997.572355,
#         "MNT": 3224.14594,
#         "MOP": 9.048878,
#         "MRO": 402.705217,
#         "MUR": 48.859485,
#         "MVR": 17.428434,
#         "MWK": 919.399651,
#         "MXN": 23.514165,
#         "MYR": 4.719103,
#         "MZN": 72.002348,
#         "NAD": 17.642758,
#         "NGN": 463.438775,
#         "NIO": 39.716833,
#         "NOK": 9.937834,
#         "NPR": 133.938088,
#         "NZD": 1.608249,
#         "OMR": 0.434268,
#         "PAB": 1.127377,
#         "PEN": 4.537669,
#         "PGK": 3.959552,
#         "PHP": 56.974078,
#         "PKR": 197.475918,
#         "PLN": 4.697219,
#         "PYG": 7716.99245,
#         "QAR": 4.107187,
#         "RON": 4.949897,
#         "RSD": 117.668534,
#         "RUB": 82.93081,
#         "RWF": 1166.87045,
#         "SAR": 4.231436,
#         "SBD": 9.078755,
#         "SCR": 16.834708,
#         "SDG": 494.075929,
#         "SEK": 10.135712,
#         "SGD": 1.535667,
#         "SHP": 1.553748,
#         "SLL": 12436.491012,
#         "SOS": 658.767777,
#         "SRD": 24.249226,
#         "STD": 23347.868197,
#         "SVC": 9.864801,
#         "SYP": 1417.684984,
#         "SZL": 17.754744,
#         "THB": 37.038788,
#         "TJS": 12.734825,
#         "TMT": 3.948092,
#         "TND": 3.229258,
#         "TOP": 2.550134,
#         "TRY": 12.671012,
#         "TTD": 7.652086,
#         "TWD": 31.358573,
#         "TZS": 2596.717062,
#         "UAH": 29.977973,
#         "UGX": 4030.298938,
#         "USD": 1.128026,
#         "UYU": 49.7444,
#         "UZS": 12110.606778,
#         "VEF": 241206127582.57767,
#         "VND": 25563.333394,
#         "VUV": 125.571453,
#         "WST": 2.891855,
#         "XAF": 655.072186,
#         "XAG": 0.04583,
#         "XAU": 0.000611,
#         "XCD": 3.048548,
#         "XDR": 0.804813,
#         "XOF": 655.014197,
#         "XPF": 118.86582,
#         "YER": 282.289007,
#         "ZAR": 17.716212,
#         "ZMK": 10153.594934,
#         "ZMW": 19.8697,
#         "ZWL": 363.224028
#     }
# }

# %% [markdown]
# ### Extracting data for a time period

# %%
time_period = base_url + "&history" + "&start_at=2017-04-26&end_at=2018-04-26" + "&symbols=GBP"
time_period
# Out:
# 'http://api.exchangeratesapi.io/v1/latest?access_key=ca644efc5035c9ca014e207937f9d706&history&start_at=2017-04-26&end_at=2018-04-26&symbols=GBP'

# %%
response = requests.get(time_period)
response.status_code
# Out:
# 200

# %%
data = response.json()
data
# Out:
# {'success': True,
#  'timestamp': 1637437444,
#  'base': 'EUR',
#  'date': '2021-11-20',
#  'rates': {'GBP': 0.838993}}

# %%
data = requests.get(time_period).json()

# %%
print(json.dumps(data, indent=4, sort_keys=True))
# Out:
# {
#     "base": "EUR",
#     "date": "2021-11-20",
#     "rates": {
#         "GBP": 0.838993
#     },
#     "success": true,
#     "timestamp": 1637437444
# }

# %% [markdown]
# ## Testing the API response to incorrect input

# %%
invalid_url = base_url + "/2019-03-01"

# %%
response = requests.get(invalid_url)
response.status_code
# Out:
# 401

# %%
data = response.json()
data
# Out:
# {'error': {'code': 'invalid_access_key',
#   'message': 'You have not supplied a valid API Access Key. [Technical Support: support@apilayer.com]'}}

# %% [markdown]
# ## Creating a simple currency converter

# %%
date = input("Please enter the date (in the format 'yyyy-mm-dd' or 'latest'): ")
# base = input("Convert from (currency): ")
curr = input("Convert to (currency): ")
quan = float(input("How much {} do you want to convert: ".format(base)))

# url = base_url + "&" + date + "&base=" + base + "&symbols=" + curr
# OR r = requests.get(base_url, params = {"base": "base", "symbols": "curr"})
# r.status_code   Or    r.ok
# Also we can add limit. For example:
# r = requests.get(base_url, params = {"base": "base", "symbols": "curr", "limit": 200})
url = base_url + "&" + date + "&symbols=" + curr
response = requests.get(url)

if(response.ok is False):
    print("\nError {}:".format(response.status_code))
    print(response.json()['error'])
    
else:
    data  = response.json()
    rate = data['rates'][curr]
    
    result = quan*rate
    
    print("\n{0} EUR is equal to {1} {2}, based upon exchange rates on {3}".format(quan,result,curr,data['date']))
# Out:
# Please enter the date (in the format 'yyyy-mm-dd' or 'latest'): 2021-06-25
# Convert to (currency): USD
# How much GBP do you want to convert: 1
#
# 1.0 EUR is equal to 1.128026 USD, based upon exchange rates on 2021-11-20

# %% [markdown]
# ## Pagination

# %%
base_site = "https://api.github.com/"

# %%
r = requests.get(base_site, params = {"description": "data science", "location": "los angeles"})
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'current_user_url': 'https://api.github.com/user',
#  'current_user_authorizations_html_url': 'https://github.com/settings/connections/applications{/client_id}',
#  'authorizations_url': 'https://api.github.com/authorizations',
#  'code_search_url': 'https://api.github.com/search/code?q={query}{&page,per_page,sort,order}',
#  'commit_search_url': 'https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}',
#  'emails_url': 'https://api.github.com/user/emails',
#  'emojis_url': 'https://api.github.com/emojis',
#  'events_url': 'https://api.github.com/events',
#  'feeds_url': 'https://api.github.com/feeds',
#  'followers_url': 'https://api.github.com/user/followers',
#  'following_url': 'https://api.github.com/user/following{/target}',
#  'gists_url': 'https://api.github.com/gists{/gist_id}',
#  'hub_url': 'https://api.github.com/hub',
#  'issue_search_url': 'https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}',
#  'issues_url': 'https://api.github.com/issues',
#  'keys_url': 'https://api.github.com/user/keys',
#  'label_search_url': 'https://api.github.com/search/labels?q={query}&repository_id={repository_id}{&page,per_page}',
#  'notifications_url': 'https://api.github.com/notifications',
#  'organization_url': 'https://api.github.com/orgs/{org}',
#  'organization_repositories_url': 'https://api.github.com/orgs/{org}/repos{?type,page,per_page,sort}',
#  'organization_teams_url': 'https://api.github.com/orgs/{org}/teams',
#  'public_gists_url': 'https://api.github.com/gists/public',
#  'rate_limit_url': 'https://api.github.com/rate_limit',
#  'repository_url': 'https://api.github.com/repos/{owner}/{repo}',
#  'repository_search_url': 'https://api.github.com/search/repositories?q={query}{&page,per_page,sort,order}',
#  'current_user_repositories_url': 'https://api.github.com/user/repos{?type,page,per_page,sort}',
#  'starred_url': 'https://api.github.com/user/starred{/owner}{/repo}',
#  'starred_gists_url': 'https://api.github.com/gists/starred',
#  'topic_search_url': 'https://api.github.com/search/topics?q={query}{&page,per_page}',
#  'user_url': 'https://api.github.com/users/{user}',
#  'user_organizations_url': 'https://api.github.com/user/orgs',
#  'user_repositories_url': 'https://api.github.com/users/{user}/repos{?type,page,per_page,sort}',
#  'user_search_url': 'https://api.github.com/search/users?q={query}{&page,per_page,sort,order}'}

# %%
len(r.json())
# Out:
# 33

# %% [markdown]
# ### The page parameters

# %%
r = requests.get(base_site)
r.ok
# Out:
# True

# %%
r.json()
# Out:
# {'current_user_url': 'https://api.github.com/user',
#  'current_user_authorizations_html_url': 'https://github.com/settings/connections/applications{/client_id}',
#  'authorizations_url': 'https://api.github.com/authorizations',
#  'code_search_url': 'https://api.github.com/search/code?q={query}{&page,per_page,sort,order}',
#  'commit_search_url': 'https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}',
#  'emails_url': 'https://api.github.com/user/emails',
#  'emojis_url': 'https://api.github.com/emojis',
#  'events_url': 'https://api.github.com/events',
#  'feeds_url': 'https://api.github.com/feeds',
#  'followers_url': 'https://api.github.com/user/followers',
#  'following_url': 'https://api.github.com/user/following{/target}',
#  'gists_url': 'https://api.github.com/gists{/gist_id}',
#  'hub_url': 'https://api.github.com/hub',
#  'issue_search_url': 'https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}',
#  'issues_url': 'https://api.github.com/issues',
#  'keys_url': 'https://api.github.com/user/keys',
#  'label_search_url': 'https://api.github.com/search/labels?q={query}&repository_id={repository_id}{&page,per_page}',
#  'notifications_url': 'https://api.github.com/notifications',
#  'organization_url': 'https://api.github.com/orgs/{org}',
#  'organization_repositories_url': 'https://api.github.com/orgs/{org}/repos{?type,page,per_page,sort}',
#  'organization_teams_url': 'https://api.github.com/orgs/{org}/teams',
#  'public_gists_url': 'https://api.github.com/gists/public',
#  'rate_limit_url': 'https://api.github.com/rate_limit',
#  'repository_url': 'https://api.github.com/repos/{owner}/{repo}',
#  'repository_search_url': 'https://api.github.com/search/repositories?q={query}{&page,per_page,sort,order}',
#  'current_user_repositories_url': 'https://api.github.com/user/repos{?type,page,per_page,sort}',
#  'starred_url': 'https://api.github.com/user/starred{/owner}{/repo}',
#  'starred_gists_url': 'https://api.github.com/gists/starred',
#  'topic_search_url': 'https://api.github.com/search/topics?q={query}{&page,per_page}',
#  'user_url': 'https://api.github.com/users/{user}',
#  'user_organizations_url': 'https://api.github.com/user/orgs',
#  'user_repositories_url': 'https://api.github.com/users/{user}/repos{?type,page,per_page,sort}',
#  'user_search_url': 'https://api.github.com/search/users?q={query}{&page,per_page,sort,order}'}

# %%
len(r.json())
# Out:
# 33

# %%
r = requests.get(base_site, params = {"page": 2})
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'current_user_url': 'https://api.github.com/user',
#  'current_user_authorizations_html_url': 'https://github.com/settings/connections/applications{/client_id}',
#  'authorizations_url': 'https://api.github.com/authorizations',
#  'code_search_url': 'https://api.github.com/search/code?q={query}{&page,per_page,sort,order}',
#  'commit_search_url': 'https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}',
#  'emails_url': 'https://api.github.com/user/emails',
#  'emojis_url': 'https://api.github.com/emojis',
#  'events_url': 'https://api.github.com/events',
#  'feeds_url': 'https://api.github.com/feeds',
#  'followers_url': 'https://api.github.com/user/followers',
#  'following_url': 'https://api.github.com/user/following{/target}',
#  'gists_url': 'https://api.github.com/gists{/gist_id}',
#  'hub_url': 'https://api.github.com/hub',
#  'issue_search_url': 'https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}',
#  'issues_url': 'https://api.github.com/issues',
#  'keys_url': 'https://api.github.com/user/keys',
#  'label_search_url': 'https://api.github.com/search/labels?q={query}&repository_id={repository_id}{&page,per_page}',
#  'notifications_url': 'https://api.github.com/notifications',
#  'organization_url': 'https://api.github.com/orgs/{org}',
#  'organization_repositories_url': 'https://api.github.com/orgs/{org}/repos{?type,page,per_page,sort}',
#  'organization_teams_url': 'https://api.github.com/orgs/{org}/teams',
#  'public_gists_url': 'https://api.github.com/gists/public',
#  'rate_limit_url': 'https://api.github.com/rate_limit',
#  'repository_url': 'https://api.github.com/repos/{owner}/{repo}',
#  'repository_search_url': 'https://api.github.com/search/repositories?q={query}{&page,per_page,sort,order}',
#  'current_user_repositories_url': 'https://api.github.com/user/repos{?type,page,per_page,sort}',
#  'starred_url': 'https://api.github.com/user/starred{/owner}{/repo}',
#  'starred_gists_url': 'https://api.github.com/gists/starred',
#  'topic_search_url': 'https://api.github.com/search/topics?q={query}{&page,per_page}',
#  'user_url': 'https://api.github.com/users/{user}',
#  'user_organizations_url': 'https://api.github.com/user/orgs',
#  'user_repositories_url': 'https://api.github.com/users/{user}/repos{?type,page,per_page,sort}',
#  'user_search_url': 'https://api.github.com/search/users?q={query}{&page,per_page,sort,order}'}

# %%
len(r.json())
# Out:
# 33

# %% [markdown]
# ### Extracting results from multiple pages

# %%
results = []

# %%
for i in range(5):
    r = requests.get(base_site, params = {"page": i+1})
    
    if len(r.json()) == 0:
        break
        
    else:
        results.extend(r.json())

# %%
len(results)
# Out:
# 165
